# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Elektrizitaetsproduktionsanlagen

# %% [markdown]
# ## Load data

# %%
import pandas as pd

# %%
df = pd.read_csv('../data/ch.bfe.elektrizitaetsproduktionsanlagen/ElectricityProductionPlant.csv')
display(type(df))
display(df.shape)
display(df)
# Out:
# pandas.core.frame.DataFrame
# (113447, 13)
#         xtf_id                   Address  PostCode          Municipality  \
# 0         5646       Rue des Creusets 41      1948               Fionnay
# 1         5686                Binenweg 5      3904                Naters
# 2         5726               Robbia 504G      7741             San Carlo
# 3         5727         Via Principale 16      7744          Campocologno
# 4         5730               Büdemli 65B      7240                Küblis
# ...        ...                       ...       ...                   ...
# 113442  175975  Chemin de la Combettaz 4      1337              Vallorbe
# 113443  175976   Route de la Condémine 7      1728               Rossens
# 113444  175977                Erlenweg 9      2543               Lengnau
# 113445  175978                Rämsen 732      9063                 Stein
# 113446  175981    Route de Chesalles 12A      1512  Chavannes sur Moudon
#
# ...

# %% [markdown]
# ## Selecting data

# %% [markdown]
# ### Single column selection

# %%
cantons = df["Canton"]
# Alternative df.Canton
display(type(cantons))
display(cantons.shape)
display(cantons)
# Out:
# pandas.core.series.Series
# (113447,)
# 0         VS
# 1         VS
# 2         GR
# 3         GR
# 4         GR
#           ..
# 113442    VD
# 113443    FR
# 113444    BE
# 113445    AR
# 113446    VD
# Name: Canton, Length: 113447, dtype: object

# %% [markdown]
# ### Mulitple columns selection

# %%
locations = df[['PostCode', 'Municipality']]
display(type(locations))
display(locations.shape)
display(locations)
# Out:
# pandas.core.frame.DataFrame
# (113447, 2)
#         PostCode          Municipality
# 0           1948               Fionnay
# 1           3904                Naters
# 2           7741             San Carlo
# 3           7744          Campocologno
# 4           7240                Küblis
# ...          ...                   ...
# 113442      1337              Vallorbe
# 113443      1728               Rossens
# 113444      2543               Lengnau
# 113445      9063                 Stein
# 113446      1512  Chavannes sur Moudon
#
# [113447 rows x 2 columns]

# %% [markdown]
# ### Filter rows

# %% [markdown]
# Conditional Series based on expression

# %%
df.PostCode == 3097
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 113442    False
# 113443    False
# 113444    False
# 113445    False
# 113446    False
# Name: PostCode, Length: 113447, dtype: bool

# %%
in_3097 = df[df.PostCode == 3097]
in_3097
# Out:
#         xtf_id                Address  PostCode     Municipality Canton  \
# 2190     11404         Freiestrasse 6      3097        Liebefeld     BE
# 2505     11970      Waldeggstrasse 51      3097  Liebefeld Köniz     BE
# 4328     16881     Feldrainstrasse 68      3097        Liebefeld     BE
# 6736     23896            Rosenweg 16      3097        Liebefeld     BE
# 8407     32109            Höheweg 42a      3097        Liebefeld     BE
# ...        ...                    ...       ...              ...    ...
# 102734  163222            Rosenweg 38      3097        Liebefeld     BE
# 103857  164617     Feldrainstrasse 62      3097        Liebefeld     BE
# 106775  167938            Höheweg 72c      3097        Liebefeld     BE
# 106776  167939           Buchenweg 18      3097        Liebefeld     BE
# 108575  170026  Gartenstadtstrasse 23      3097        Liebefeld     BE
#
#        BeginningOfOperation  InitialPower  TotalPower MainCategory  \
# ...

# %%
in_3097_5012 = df[(df.PostCode == 3097) | (df.PostCode == 5012)]
in_3097_5012
# Out:
#         xtf_id                Address  PostCode     Municipality Canton  \
# 2190     11404         Freiestrasse 6      3097        Liebefeld     BE
# 2505     11970      Waldeggstrasse 51      3097  Liebefeld Köniz     BE
# 4173     16435        Bäckerstrasse 2      5012      Schönenwerd     SO
# 4328     16881     Feldrainstrasse 68      3097        Liebefeld     BE
# 6736     23896            Rosenweg 16      3097        Liebefeld     BE
# ...        ...                    ...       ...              ...    ...
# 103857  164617     Feldrainstrasse 62      3097        Liebefeld     BE
# 106775  167938            Höheweg 72c      3097        Liebefeld     BE
# 106776  167939           Buchenweg 18      3097        Liebefeld     BE
# 107153  168359         Dorfstrasse 36      5012        Eppenberg     SO
# 108575  170026  Gartenstadtstrasse 23      3097        Liebefeld     BE
#
#        BeginningOfOperation  InitialPower  TotalPower MainCategory  \
# ...

# %%
# Out:
#         xtf_id                   Address  PostCode          Municipality  \
# 0         5646       Rue des Creusets 41      1948               Fionnay
# 1         5686                Binenweg 5      3904                Naters
# 2         5726               Robbia 504G      7741             San Carlo
# 3         5727         Via Principale 16      7744          Campocologno
# 4         5730               Büdemli 65B      7240                Küblis
# ...        ...                       ...       ...                   ...
# 113442  175975  Chemin de la Combettaz 4      1337              Vallorbe
# 113443  175976   Route de la Condémine 7      1728               Rossens
# 113444  175977                Erlenweg 9      2543               Lengnau
# 113445  175978                Rämsen 732      9063                 Stein
# 113446  175981    Route de Chesalles 12A      1512  Chavannes sur Moudon
#
#        Canton BeginningOfOperation  InitialPower  TotalPower MainCategory  \
# ...

# %% [markdown]
# ## Code cells
#
#
#
# In the case of code cells, the output of the last statement is always output under the cell.
#
# The cell is executed using Control-Enter

# %%
1+5
# Out:
# 6

# %% [markdown]
# If several statements are to be output, this can be done using `print ()`
