# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Wöchentliche Todesfälle, 2010-2019
#
# https://opendata.swiss/de/dataset/wochentliche-todesfalle-2010-2019

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10) 

url='https://www.bfs.admin.ch/bfsstatic/dam/assets/12607336/master'

df = pd.read_csv(url, sep=';', parse_dates=['Endend' ], encoding='ISO 8859-1', nrows=1042)
df
# Out:
#         KJ  Kalenderwoche     Endend Alter  Anzahl_Todesfalle  Erwartung  \
# 0     2010              1 2010-10-01  0-64                193        195
# 1     2010              2 2010-01-17  0-64                198        195
# 2     2010              3 2010-01-24  0-64                191        194
# 3     2010              4 2010-01-31  0-64                207        194
# 4     2010              5 2010-07-02  0-64                175        193
# ...    ...            ...        ...   ...                ...        ...
# 1037  2019             48 2019-01-12   65+               1183       1146
# 1038  2019             49 2019-08-12   65+               1057       1158
# 1039  2019             50 2019-12-15   65+               1189       1170
# 1040  2019             51 2019-12-22   65+               1200       1181
# 1041  2019             52 2019-12-29   65+               1157       1193
#
#       untGrenze  obeGrenze  Exzess
# 0           159        231     NaN
# ...
