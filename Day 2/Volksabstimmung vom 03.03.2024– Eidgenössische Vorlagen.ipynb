# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Volksabstimmung vom 03.03.2024– Eidgenössische Vorlagen
#
# https://opendata.swiss/de/dataset/echtzeitdaten-am-abstimmungstag-zu-eidgenoessischen-abstimmungsvorlagen/resource/4a12e5a3-ee2c-4d1e-ab39-08ed2fc5d75d

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import urllib.request
import json
import gzip

plt.rcParams["figure.figsize"] = (20, 10) 


def getJsonData(url):
    operUrl = urllib.request.urlopen(url)
    if(operUrl.getcode()==200):
        data = operUrl.read()
        jsonData = json.loads(data)
    else:
        print("Error receiving data", operUrl.getcode())
    return jsonData

url='https://app-prod-static-voteinfo.s3.eu-central-1.amazonaws.com/v1/ogd/sd-t-17-02-20240303-eidgAbstimmung.json'

jsonData = getJsonData(url)

# %%
vorlage0 = jsonData['schweiz']['vorlagen'][0]

kantone = vorlage0['kantone']

json.dumps(kantone)
# Out:
# '[{"geoLevelnummer": "1", "geoLevelname": "Z\\u00fcrich", "resultat": {"vorlageBeendet": true, "gebietAusgezaehlt": true, "jaStimmenInProzent": 52.086905192, "jaStimmenAbsolut": 295601, "neinStimmenAbsolut": 271914, "stimmbeteiligungInProzent": 58.892003366, "eingelegteStimmzettel": 570425, "anzahlStimmberechtigte": 968595, "gueltigeStimmen": 567515}, "bezirke": [{"geoLevelnummer": "101", "geoLevelname": "Bezirk Affoltern", "resultat": {"gebietAusgezaehlt": true, "jaStimmenInProzent": 48.295161013, "jaStimmenAbsolut": 11218, "neinStimmenAbsolut": 12010, "stimmbeteiligungInProzent": 64.259927798, "eingelegteStimmzettel": 23318, "anzahlStimmberechtigte": 36287, "gueltigeStimmen": 23228}}, {"geoLevelnummer": "102", "geoLevelname": "Bezirk Andelfingen", "resultat": {"gebietAusgezaehlt": true, "jaStimmenInProzent": 46.771438333, "jaStimmenAbsolut": 6845, "neinStimmenAbsolut": 7790, "stimmbeteiligungInProzent": 64.51683716, "eingelegteStimmzettel": 14695, "anzahlStimmberechtigte": 22777, "
# ...

# %%
pd.read_json(json.dumps(kantone)).explode('gemeinden')
# Out:
#     geoLevelnummer geoLevelname  \
# 0                1       Zürich
# 0                1       Zürich
# 0                1       Zürich
# 0                1       Zürich
# 0                1       Zürich
# ..             ...          ...
# 25              26         Jura
# 25              26         Jura
# 25              26         Jura
# 25              26         Jura
# 25              26         Jura
#
#                                              resultat  \
# 0   {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 0   {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 0   {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 0   {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 0   {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# ..                                                ...
# 25  {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 25  {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# 25  {'vorlageBeendet': True, 'gebietAusgezaehlt': ...
# ...

# %%
pd.json_normalize(kantone)
# Out:
#    geoLevelnummer                      geoLevelname  \
# 0               1                            Zürich
# 1               2                      Bern / Berne
# 2               3                            Luzern
# 3               4                               Uri
# 4               5                            Schwyz
# 5               6                          Obwalden
# 6               7                         Nidwalden
# 7               8                            Glarus
# 8               9                               Zug
# 9              10               Fribourg / Freiburg
# 10             11                         Solothurn
# 11             12                       Basel-Stadt
# 12             13                  Basel-Landschaft
# 13             14                      Schaffhausen
# 14             15            Appenzell Ausserrhoden
# 15             16             Appenzell Innerrhoden
# 16             17                        St. Gallen
# ...
