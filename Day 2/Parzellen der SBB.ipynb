# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Parzellen der SBB
#
# https://opendata.swiss/de/dataset/parzellen-der-sbb

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10) 

url='https://data.sbb.ch/api/v2/catalog/datasets/parzellen-der-sbb/exports/csv'

df = pd.read_csv(url, sep=';', encoding='UTF-8')
df
# Out:
#                                geo_point_2d  \
# 0     47.195272295700846, 7.660630160713772
# 1      47.50628475279594, 9.210845214895768
# 2      46.72564298980443, 8.619139276433536
# 3     46.600757373986546, 8.658288682666358
# 4      47.24810928853455, 8.708518121775151
# ...                                     ...
# 7586  46.85315996474189, 6.9830716556307335
# 7587  46.354160814840725, 8.960480481086188
# 7588    47.0193796600595, 6.854170704754138
# 7589   47.00305136411163, 6.846393477180763
# 7590   47.31061798497554, 8.189084936181331
#
#                                               geo_shape       gemeinde  \
# 0     {"coordinates": [[[7.660939349057923, 47.19540...         Bolken
# 1     {"coordinates": [[[9.20993493864626, 47.506946...    Hohentannen
# 2     {"coordinates": [[[8.619119487614633, 46.72553...     Gurtnellen
# 3     {"coordinates": [[[8.65798986666701, 46.600733...      Andermatt
# 4     {"coordinates": [[[8.708522758602367, 47.24822...          Stäfa
# ...
