# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Aufführungen von Max Frisch Theaterstücken seit 1945
#
# https://opendata.swiss/de/dataset/auffuhrungen-von-max-frisch-theaterstucken-seit-1945
#
# execute `pip install openpyxl` if .xlsx cannot be parsed

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10)

url='http://download.library.ethz.ch/opendata/Theaterauff%c3%bchrungen%20MF%20von%201945%20bis%20heute.xlsx'

df = pd.read_excel(url, sheet_name='1945-2020', nrows=730)
df
# Out:
#     Premierendatum Aufführungsart                            Stück  \
# 0       1945-03-23             UA            Nun singen sie wieder
# 1       1945-04-01            NaN            Nun singen sie wieder
# 2       1945-04-10            NaN            Nun singen sie wieder
# 3       1945-10-24            NaN            Nun singen sie wieder
# 4       1946-03-07             UA                       Santa Cruz
# ..             ...            ...                              ...
# 725     2019-09-16            NaN  Biedermann und die Brandstifter
# 726     2020-01-23            NaN  Der Mensch erscheint im Holozän
# 727     2020-02-14            NaN                    Graf Öderland
# 728     2020-03-01            NaN  Biedermann und die Brandstifter
# 729     2020-03-27            NaN  Der Mensch erscheint im Holozän
#
#                                     Theater / Ensemble               Ort Land  \
# 0                                Schauspielhaus Zürich            Zürich  CHE
# ...
