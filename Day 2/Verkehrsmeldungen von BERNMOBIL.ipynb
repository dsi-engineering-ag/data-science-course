# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Verkehrsmeldungen von BERNMOBIL
#
# https://opendata.swiss/de/dataset/verkehrsmeldungen-bernmobil

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10)

url='https://github.com/BERNMOBIL/opendata-verkehrsmeldungen/blob/dfb0c24b67aa6cbc7b0e36d053e0c5e934bebbe6/incidents.csv?raw=true'

df = pd.read_csv(url, sep=';', index_col='ID', parse_dates=['Start Ereigniszeitpunkt', 'Ende Ereigniszeitpunkt', 'Zeitpunkt Meldung beendet', 'Start Publikationszeitpunkt', 'Ende Publikationszeitpunkt'])
df
# Out:
#                                                                       Titel  \
# ID
# 5ef4931efcfa1d90e0289851  Linie 19: Haltestelle Zieglerspital nicht bedient
# 5f1022021c53e13a143b4d0e                      Linie 9B: Betrieb eingestellt
# 5f1022301c53e13a143b4d0f                      Linie 23: Betrieb eingestellt
# 5f2a5631fcfa1d90e02898e8                  Linie 23: Unregelmässiger Betrieb
# 5f2a589ffcfa1d90e02898e9                                Linie 23: Baustelle
# ...                                                                     ...
# 610efc071c53e121146cef73  Linien 9, 11, 20 und 21: Verspätungen und unre...
# 610f50f41c53e121146cefa2                               Linie 12: Verspätung
# 610fd2d029254f0d4824dc04  Linie 8: Verspätungen und unregelmässiger Betrieb
# 611035eb29254f0d4824dc1f            Linie 30: Verspätungen und Kursausfälle
# 611053331c53e121146cefa7                              Linie 6: Verspätungen
#
# ...
