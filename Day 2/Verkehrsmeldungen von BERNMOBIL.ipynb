# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Verkehrsmeldungen von BERNMOBIL
#
# https://opendata.swiss/de/dataset/verkehrsmeldungen-bernmobil

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10)

url='https://github.com/BERNMOBIL/opendata-verkehrsmeldungen/raw/master/incidents.csv'

df = pd.read_csv(url, sep=';', index_col='ID', parse_dates=['Start Ereigniszeitpunkt', 'Ende Ereigniszeitpunkt', 'Zeitpunkt Meldung beendet', 'Start Publikationszeitpunkt', 'Ende Publikationszeitpunkt'])
df
# Out:
#                                                                       Titel  \
# ID
# 5e70c840fcfa1d90e02896df  Linien M3, M4, M5, M6, M7, M9, M18, M19, M20, ...
# 5e70c840fcfa1d90e02896df  Linien M3, M4, M5, M6, M7, M9, M18, M19, M20, ...
# 5e70c840fcfa1d90e02896df  Linien M3, M4, M5, M6, M7, M9, M18, M19, M20, ...
# 5e70c840fcfa1d90e02896df  Linien M3, M4, M5, M6, M7, M9, M18, M19, M20, ...
# 5e70c840fcfa1d90e02896df  Linien M3, M4, M5, M6, M7, M9, M18, M19, M20, ...
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c                 Linie 10: Unregelmässiger Betrieb
# 60c4c65fe1060b1110d48cf0                             Linie 31: Verspätungen
# 60c4c73d29254f27fcbdf98a                              Linie 19: Kursausfall
# 60c4cf7529254f27fcbdf98c                              Linie 19: Kursausfall
# 60c5b4ca29254f27fcbdf9ce               Technische Störung an der Gurtenbahn
#
#                                       Transportunternehmen  \
# ID
# 5e70c840fcfa1d90e02896df  Städtische Verkehrsbetriebe Bern
# 5e70c840fcfa1d90e02896df  Städtische Verkehrsbetriebe Bern
# 5e70c840fcfa1d90e02896df  Städtische Verkehrsbetriebe Bern
# 5e70c840fcfa1d90e02896df  Städtische Verkehrsbetriebe Bern
# 5e70c840fcfa1d90e02896df  Städtische Verkehrsbetriebe Bern
# ...                                                    ...
# 60c4b3ac29254f27fcbdf97c  Städtische Verkehrsbetriebe Bern
# 60c4c65fe1060b1110d48cf0  Städtische Verkehrsbetriebe Bern
# 60c4c73d29254f27fcbdf98a  Städtische Verkehrsbetriebe Bern
# 60c4cf7529254f27fcbdf98c  Städtische Verkehrsbetriebe Bern
# 60c5b4ca29254f27fcbdf9ce  Städtische Verkehrsbetriebe Bern
#
#                                                               Kurze Meldung  \
# ID
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c  12.06.2021, 15:15 Uhr: Auf der Linie 10 ist in...
# 60c4c65fe1060b1110d48cf0  12.06.2021, 16:35 Uhr: Auf der Linie 31 ist in...
# 60c4c73d29254f27fcbdf98a  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c4cf7529254f27fcbdf98c  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c5b4ca29254f27fcbdf9ce  13.06.2021, 09:23 Uhr: Technische Störung an d...
#
#                                                               Lange Meldung  \
# ID
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c  12.06.2021, 15:15 Uhr: Auf der Linie 10 ist in...
# 60c4c65fe1060b1110d48cf0  12.06.2021, 16:35 Uhr: Auf der Linie 31 ist in...
# 60c4c73d29254f27fcbdf98a  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c4cf7529254f27fcbdf98c  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c5b4ca29254f27fcbdf9ce  13.06.2021, 09:23 Uhr: Technische Störung an d...
#
#                                                          Erweiterte Meldung  \
# ID
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# 5e70c840fcfa1d90e02896df  Vorläufig kein MOONLINER Betrieb. Weitere Info...
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c  12.06.2021, 15:15 Uhr: Auf der Linie 10 ist in...
# 60c4c65fe1060b1110d48cf0  12.06.2021, 16:35 Uhr: Auf der Linie 31 ist in...
# 60c4c73d29254f27fcbdf98a  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c4cf7529254f27fcbdf98c  Auf der Linie 19 fällt infolge einer Betriebss...
# 60c5b4ca29254f27fcbdf9ce  13.06.2021, 09:23 Uhr: Technische Störung an d...
#
#                                                                  Endmeldung  \
# ID
# 5e70c840fcfa1d90e02896df  Die Linien M3, M4, M5, M6, M7, M9, M18, M19, M...
# 5e70c840fcfa1d90e02896df  Die Linien M3, M4, M5, M6, M7, M9, M18, M19, M...
# 5e70c840fcfa1d90e02896df  Die Linien M3, M4, M5, M6, M7, M9, M18, M19, M...
# 5e70c840fcfa1d90e02896df  Die Linien M3, M4, M5, M6, M7, M9, M18, M19, M...
# 5e70c840fcfa1d90e02896df  Die Linien M3, M4, M5, M6, M7, M9, M18, M19, M...
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c          Die Linie 10 fährt wieder nach Fahrplan.
# 60c4c65fe1060b1110d48cf0          Die Linie 31 fährt wieder nach Fahrplan.
# 60c4c73d29254f27fcbdf98a          Die Linie 19 fährt wieder nach Fahrplan.
# 60c4cf7529254f27fcbdf98c          Die Linie 19 fährt wieder nach Fahrplan.
# 60c5b4ca29254f27fcbdf9ce  Die Gurtenbahn fährt wieder. Es besteht kein B...
#
#                          Start Ereigniszeitpunkt Ende Ereigniszeitpunkt  \
# ID
# 5e70c840fcfa1d90e02896df     2020-03-20 01:00:00    2020-06-28 03:50:00
# 5e70c840fcfa1d90e02896df     2020-03-20 01:00:00    2020-06-28 03:50:00
# 5e70c840fcfa1d90e02896df     2020-03-20 01:00:00    2020-06-28 03:50:00
# 5e70c840fcfa1d90e02896df     2020-03-20 01:00:00    2020-06-28 03:50:00
# 5e70c840fcfa1d90e02896df     2020-03-20 01:00:00    2020-06-28 03:50:00
# ...                                          ...                    ...
# 60c4b3ac29254f27fcbdf97c     2021-12-06 15:15:00    2021-12-06 16:15:31
# 5e70c840fcfa1d90e02896df  incident.severity.INCIDENT
# 5e70c840fcfa1d90e02896df  incident.severity.INCIDENT
# 5e70c840fcfa1d90e02896df  incident.severity.INCIDENT
# ...                                              ...
# 60c4b3ac29254f27fcbdf97c  incident.severity.INCIDENT
# 60c4c65fe1060b1110d48cf0  incident.severity.INCIDENT
# 60c4c73d29254f27fcbdf98a  incident.severity.INCIDENT
# 60c4cf7529254f27fcbdf98c  incident.severity.INCIDENT
# 60c5b4ca29254f27fcbdf9ce  incident.severity.INCIDENT
#
#                                                  Template  \
# ID
# 5e70c840fcfa1d90e02896df   Linie: Unregelmässiger Betrieb
# 5e70c840fcfa1d90e02896df   Linie: Unregelmässiger Betrieb
# 5e70c840fcfa1d90e02896df   Linie: Unregelmässiger Betrieb
# 5e70c840fcfa1d90e02896df   Linie: Unregelmässiger Betrieb
# 5e70c840fcfa1d90e02896df   Linie: Unregelmässiger Betrieb
# ...                                                   ...
# 60c4b3ac29254f27fcbdf97c  Linie: Unregelmässiger Betrieb
# 60c4c65fe1060b1110d48cf0                Linie: Verspätung
# 60c4c73d29254f27fcbdf98a                Kurs: Kursausfall
# 60c4cf7529254f27fcbdf98c                Kurs: Kursausfall
# 60c5b4ca29254f27fcbdf9ce  Linie: Unregelmässiger Betrieb
#
#                                                                      Medien  \
# ID
# 5e70c840fcfa1d90e02896df                                    MEZI, OEVPLUSCH
# 5e70c840fcfa1d90e02896df                                    MEZI, OEVPLUSCH
# 5e70c840fcfa1d90e02896df                                    MEZI, OEVPLUSCH
# 5e70c840fcfa1d90e02896df                                    MEZI, OEVPLUSCH
# 5e70c840fcfa1d90e02896df                                    MEZI, OEVPLUSCH
# ...                                                                     ...
# 60c4b3ac29254f27fcbdf97c  ONLINE, MEZI, FGIBILDSCHIRM, MONITOR, INFOPOIN...
# 60c4c65fe1060b1110d48cf0  ONLINE, MEZI, FGIBILDSCHIRM, MONITOR, INFOPOIN...
# 60c4c73d29254f27fcbdf98a  ONLINE, MEZI, MONITOR, INFOPOINT, TWITTER, GTF...
# 60c4cf7529254f27fcbdf98c  ONLINE, MEZI, MONITOR, INFOPOINT, TWITTER, GTF...
# 60c5b4ca29254f27fcbdf9ce  ONLINE, MEZI, FGIBILDSCHIRM, MONITOR, INFOPOIN...
#
#                          Linien Haltestelle
# ID
# 5e70c840fcfa1d90e02896df     M3         NaN
# 5e70c840fcfa1d90e02896df     M4         NaN
# 5e70c840fcfa1d90e02896df     M5         NaN
# 5e70c840fcfa1d90e02896df     M6         NaN
# 5e70c840fcfa1d90e02896df     M7         NaN
# ...                         ...         ...
# 60c4b3ac29254f27fcbdf97c     10         NaN
# 60c4c65fe1060b1110d48cf0     31         NaN
# 60c4c73d29254f27fcbdf98a     19         NaN
# 60c4cf7529254f27fcbdf98c     19         NaN
# 60c5b4ca29254f27fcbdf9ce      9         NaN
#
# [2480 rows x 18 columns]
