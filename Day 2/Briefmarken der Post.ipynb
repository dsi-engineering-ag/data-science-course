# %% [markdown]
# <img src="https://dsiag.ch/images/dsi_rgb.png" alt="dsi logo" width="100" style="position: absolute; right: 0px;"/>
#
# # Briefmarken der Post
#
# https://opendata.swiss/de/dataset/briefmarken-der-post

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams["figure.figsize"] = (20, 10)
pd.set_option("display.max_columns", None)

url='https://swisspost.opendatasoft.com/api/v2/catalog/datasets/stamps_swisspost/exports/csv'

df = pd.read_csv(url, sep=';', parse_dates=['verkauf_philatelie_ab', 'verkauf_philatelie_bis_oder_so_lange_vorrat', 'gultig_unbeschrankt_ab','verkauf_filialen_ab_so_lange_vorrat' ])
df
# Out:
#                                            markenthema  \
# 0    125 Jahre Schynige Platte-Bahn und Wengernalpbahn
# 1                                        Pro Juventute
# 2                                   Schweizer Bahnhöfe
# 3                                     Tiere des Waldes
# 4                                         Creux du Van
# ..                                                 ...
# 103       Gemeinschaftsausgabe Dominikanische Republik
# 104                               TdBM 2016 Oberaargau
# 105                       Niklaus von Flüe 1417 – 2017
# 106                                        Weihnachten
# 107                                        Quittenduft
#
#                 briefmarkenart                 type_de_timbre_poste  \
# 0                 Sondermarken               Timbres-poste spéciaux
# 1    Sondermarken mit Zuschlag  Timbres-poste spéciaux avec surtaxe
# 2                  Dauermarken             Timbres-poste ordinaires
# ...
